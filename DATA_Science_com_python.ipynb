# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardopaimsilva/RepGitAtividade/blob/master/DATA_Science_com_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
uri ="https://raw.githubusercontent.com/weltonvaz/enem-1/master/train.csv"
enem = pd.read_csv(uri)
enem.head()
# Out:
#    Unnamed: 0                              NU_INSCRICAO  ...  Q049  Q050
# 0           1  ed50e8aaa58e7a806c337585efee9ca41f1eb1ad  ...     B     D
# 1           2  2c3acac4b33ec2b195d77e7c04a2d75727fad723  ...     C     A
# 2           3  f4545f8ccb9ff5c8aad7d32951b3f251a26e6568  ...     B     A
# 3           4  3d6ec248fef899c414e77f82d5c6d2bffbeaf7fe  ...     A     A
# 4           5  bf896ac8d3ecadd6dba1dfbf50110afcbf5d3268  ...     A     A
#
# [5 rows x 167 columns]

# %%
enem.columns
# Out:
# Index(['Unnamed: 0', 'NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL',
#        ...
#        'Q041', 'Q042', 'Q043', 'Q044', 'Q045', 'Q046', 'Q047', 'Q048', 'Q049',
#        'Q050'],
#       dtype='object', length=167)

# %%
enem["NU_ANO"]
# Out:
# 0        2016
# 1        2016
# 2        2016
# 3        2016
# 4        2016
#          ...
# 13725    2016
# 13726    2016
# 13727    2016
# 13728    2016
# 13729    2016
# Name: NU_ANO, Length: 13730, dtype: int64

# %%
enem.describe()
# Out:
#          Unnamed: 0   NU_ANO  ...          Q040         Q041
# count  13730.000000  13730.0  ...  13730.000000  2938.000000
# mean    2288.173926   2016.0  ...      4.442098     3.671545
# std     1321.230607      0.0  ...      1.181549     1.746444
# min        0.000000   2016.0  ...      0.000000     0.000000
# 25%     1144.000000   2016.0  ...      4.000000     3.000000
# 50%     2288.000000   2016.0  ...      5.000000     5.000000
# 75%     3432.000000   2016.0  ...      5.000000     5.000000
# max     4586.000000   2016.0  ...      5.000000     5.000000
#
# [8 rows x 107 columns]

# %%
enem["NU_NOTA_REDACAO"]
# Out:
# 0        520.0
# 1        580.0
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 13725    440.0
# 13726    560.0
# 13727    600.0
# 13728    460.0
# 13729    520.0
# Name: NU_NOTA_REDACAO, Length: 13730, dtype: float64

# %%
enem["NU_NOTA_REDACAO"].unique()
# Out:
# array([ 520.,  580.,   nan,  620.,  560.,  680.,  360.,  720.,  460.,
#         780.,  500.,  400.,  440.,  600.,  760.,  420.,  640.,  480.,
#         320.,  380.,  540.,  660.,    0.,  260.,  840.,  940.,  340.,
#         740.,  700.,  280.,  800.,  300.,  180.,  860.,  900.,  120.,
#         200.,  220.,  960.,  240.,  880.,  140.,  160.,  820.,  920.,
#          80.,  650., 1000.,   60.,  466.,   40.,  184.,  980.,  566.])

# %%
enem["NU_NOTA_REDACAO"].mean()
# Out:
# 529.0482581663871

# %%
enem["NU_NOTA_REDACAO"].min()
# Out:
# 0.0

# %%
enem["NU_NOTA_REDACAO"].max()
# Out:
# 1000.0

# %%
enem.NU_NOTA_REDACAO.plot(kind='hist')
